# %%
# %matplotlib inline

import matplotlib.pyplot as plt

import healpy as hp

import numpy as np

import tensorflow as tf

from deepsphere import HealpyGCNN
from deepsphere import healpy_layers as hp_layer
from deepsphere import utils

from tqdm import tqdm

# %% [markdown]
# ### Generative Models
#
# This notebook gives a quick example on how to use the transpose pseudo convolutions in DeepSphere to train a simple auto-encoder.
#
# ![image.png](attachment:image.png)
#
# The transpose pseudo convolutions use the healpy pixelization scheme to increase the nside of the data, making them useful for generative models.

# %% [markdown]
# ### 1 Data loading
#
# The data consists of a toy dataset that is sufficiently small to have fun with. It is made of 200 maps of size `NSIDE=64` splitted into 2 classes.
#
# The maps contain a Gaussian random field realisations produced with Synfast function from Healpy package.
# The input power spectra were taken from LambdaCDM model with two sets of parameters.
# These maps are not realistic cosmological mass maps, just a toy dataset.
# We downsampled them to `Nside=64` in order to make the processing faster.

# %%
data = np.load('../data/maps_downsampled_64.npz')
assert(len(data['class1']) == len(data['class2']))
nclass = len(data['class1'])

# %% [markdown]
# We only need the first class in this notebook. Further, we will smooth the data a bit.

# %%
training_data = []
for m in data['class1']:
    m = hp.reorder(m, n2r=True)
    m = hp.smoothing(m, fwhm=.05, verbose=False)
    m = hp.reorder(m, r2n=True)
    training_data.append(100*m.astype(np.float32)[:,None])
training_data = np.array(training_data)

# %%
cmin = np.min(training_data)
cmax = np.max(training_data)
cm = plt.cm.RdBu_r
hp.mollview(training_data[0,:,0], title='class 1', nest=True, cmap=cm, min=cmin, max=cmax)

# %% [markdown]
# ### 2 A simple auto encoder
#
# We implement a simple auto-encoder class and train it on the maps

# %%
class auto_encoder(tf.keras.Model):
    def __init__(self, encoder_layer, decoder_layer, nside, indices):
        """
        Inits the auto-encoder with layers for the encoder and the decoder
        """
        # this line is necessary for all Model subclasses
        super(auto_encoder, self).__init__(name="")
        
        # save some properties
        self.nside = nside
        self.indices = indices
        
        # init the encoder and the decoder
        print("Initializing the encoder...")
        self.encoder = HealpyGCNN(nside=nside, indices=indices, layers=encoder_layer)
        
        # get the bottle neck nside and indices
        self.bottle_neck_nside = self.encoder.nside_out
        self.bottle_neck_indices = self.encoder._transform_indices(nside_in=self.nside, 
                                                        nside_out=self.bottle_neck_nside, 
                                                        indices=self.indices)
        
        print("Initializing the decoder...")
        self.decoder = HealpyGCNN(nside=self.bottle_neck_nside, 
                                  indices=self.bottle_neck_indices, 
                                  layers=decoder_layer)
        
    def summary(self, *args, **kwargs):
        """
        A wrapper for the summary routines of the decoder and encoder
        """
        print("Encoder summary:")
        self.encoder.summary(*args, **kwargs)
        print("Decoder summary:")
        self.decoder.summary(*args, **kwargs)
        
    def call(self, input_tensor, training=False, *args, **kwargs):
        """
        Calls the autoencoder
        """
        bottle_neck = self.encoder(input_tensor, training=training, *args, **kwargs)
        reconstruction = self.decoder(bottle_neck, training=training, *args, **kwargs)
        
        return reconstruction

# %% [markdown]
# Now we define some layers for the encoder and the decoder

# %%
K = 5
encoder_layers = [hp_layer.HealpyPseudoConv(p=1, Fout=4, activation="elu"),
                  hp_layer.HealpyPseudoConv(p=1, Fout=8, activation="elu"),
                  hp_layer.HealpyPseudoConv(p=1, Fout=16, activation="elu"),
                  hp_layer.HealpyChebyshev(K=K, Fout=16, use_bias=True, use_bn=False, 
                                   activation="elu"),
                  tf.keras.layers.LayerNormalization(axis=1),
                  hp_layer.HealpyChebyshev(K=K, Fout=16, use_bias=True, use_bn=False, 
                                   activation="elu"),
                  tf.keras.layers.LayerNormalization(axis=1),
                  hp_layer.HealpyChebyshev(K=K, Fout=16, use_bias=True, use_bn=False, 
                                   activation="linear"),]

decoder_layers = [hp_layer.HealpyChebyshev(K=K, Fout=16, use_bias=True, use_bn=False, 
                                   activation="elu"),
                  tf.keras.layers.LayerNormalization(axis=1),
                  hp_layer.HealpyChebyshev(K=K, Fout=16, use_bias=True, use_bn=False, 
                                           activation="elu"),
                  tf.keras.layers.LayerNormalization(axis=1),
                  hp_layer.HealpyChebyshev(K=K, Fout=16, use_bias=True, use_bn=False, 
                                           activation="elu"),
                  tf.keras.layers.LayerNormalization(axis=1),
                  hp_layer.HealpyPseudoConv_Transpose(p=1, Fout=16, activation="elu"),
                  hp_layer.HealpyChebyshev(K=K, Fout=16, use_bias=True, use_bn=False, 
                                   activation="elu"),
                  hp_layer.HealpyPseudoConv_Transpose(p=1, Fout=16, activation="elu"),
                  hp_layer.HealpyChebyshev(K=K, Fout=16, use_bias=True, use_bn=False, 
                                   activation="elu"),
                  hp_layer.HealpyPseudoConv_Transpose(p=1, Fout=1, activation="linear")]

# %%
# init the model

# %%
nside = 64
n_pix = hp.nside2npix(nside)
indices = np.arange(n_pix)
model = auto_encoder(encoder_layers, decoder_layers, nside, indices)
model.build(input_shape=(None, len(indices), 1))
model.summary(110)
# Out:
# Initializing the encoder...
# WARNING: This network assumes that everything concerning healpy is in NEST ordering...
# Detected a reduction factor of 8.0, the input with nside 64 will be transformed to 8 during a forward pass. Checking for consistency with indices...
# indices seem consistent...
# Initializing the decoder...
# WARNING: This network assumes that everything concerning healpy is in NEST ordering...
# Detected a reduction factor of 0.125, the input with nside 8 will be transformed to 64 during a forward pass. Checking for consistency with indices...
# indices seem consistent...
# Encoder summary:
# Model: "healpy_gcnn_1"
# ______________________________________________________________________________________________________________
# Layer (type)                                     Output Shape                                Param #
# ==============================================================================================================
# healpy_pseudo_conv (HealpyPseudoConv)            (None, 12288, 4)                            20
# ______________________________________________________________________________________________________________
# healpy_pseudo_conv_1 (HealpyPseudoConv)          (None, 3072, 8)                             136
# ______________________________________________________________________________________________________________
# healpy_pseudo_conv_2 (HealpyPseudoConv)          (None, 768, 16)                             528
# ______________________________________________________________________________________________________________
# chebyshev (Chebyshev)                            (None, 768, 16)                             1296
# ______________________________________________________________________________________________________________
# layer_normalization (LayerNormalization)         (None, 768, 16)                             1536
# ______________________________________________________________________________________________________________
# chebyshev_1 (Chebyshev)                          (None, 768, 16)                             1296
# ______________________________________________________________________________________________________________
# layer_normalization_1 (LayerNormalization)       (None, 768, 16)                             1536
# ______________________________________________________________________________________________________________
# chebyshev_2 (Chebyshev)                          (None, 768, 16)                             1296
# ==============================================================================================================
# Total params: 7,644
# Trainable params: 7,644
# Non-trainable params: 0
# ______________________________________________________________________________________________________________
# Decoder summary:
# Model: "healpy_gcnn_3"
# ______________________________________________________________________________________________________________
# Layer (type)                                     Output Shape                                Param #
# ==============================================================================================================
# chebyshev_3 (Chebyshev)                          (None, 768, 16)                             1296
# ______________________________________________________________________________________________________________
# layer_normalization_2 (LayerNormalization)       (None, 768, 16)                             1536
# ______________________________________________________________________________________________________________
# chebyshev_4 (Chebyshev)                          (None, 768, 16)                             1296
# ______________________________________________________________________________________________________________
# layer_normalization_3 (LayerNormalization)       (None, 768, 16)                             1536
# ______________________________________________________________________________________________________________
# chebyshev_5 (Chebyshev)                          (None, 768, 16)                             1296
# ______________________________________________________________________________________________________________
# layer_normalization_4 (LayerNormalization)       (None, 768, 16)                             1536
# ______________________________________________________________________________________________________________
# healpy_pseudo_conv__transpose (HealpyPseudoConv_ (None, 3072, 16)                            1040
# ______________________________________________________________________________________________________________
# chebyshev_6 (Chebyshev)                          (None, 3072, 16)                            1296
# ______________________________________________________________________________________________________________
# healpy_pseudo_conv__transpose_1 (HealpyPseudoCon (None, 12288, 16)                           1040
# ______________________________________________________________________________________________________________
# chebyshev_7 (Chebyshev)                          (None, 12288, 16)                           1296
# ______________________________________________________________________________________________________________
# healpy_pseudo_conv__transpose_2 (HealpyPseudoCon (None, 49152, 1)                            65
# ==============================================================================================================
# Total params: 13,233
# Trainable params: 13,233
# Non-trainable params: 0
# ______________________________________________________________________________________________________________

# %% [markdown]
# Note that for this simple toy model we chose a bottle neck that is only 4 times smaller than the input data.

# %% [markdown]
# ### 3 Training the model
#
# We use again the `model.compile()` and `model.fit()` routines to train the model. Note that we leave out a training and validation data split.

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1e-2),
              loss="MAE",
              metrics=["MAE"],
)

# %%
print("Fit model on training data")
history = model.fit(
    x=training_data,
    y=training_data,
    batch_size=5,
    epochs=50,
)
# Out:
# Fit model on training data
# Epoch 1/50
# 20/20 [==============================] - 6s 315ms/step - loss: 0.1468 - MAE: 0.1468
# Epoch 2/50
# 20/20 [==============================] - 6s 309ms/step - loss: 0.1043 - MAE: 0.1043
# Epoch 3/50
# 20/20 [==============================] - 6s 300ms/step - loss: 0.0980 - MAE: 0.0980
# Epoch 4/50
# 20/20 [==============================] - 6s 305ms/step - loss: 0.0959 - MAE: 0.0959
# Epoch 5/50
# 20/20 [==============================] - 7s 358ms/step - loss: 0.0951 - MAE: 0.0951
# Epoch 6/50
# 20/20 [==============================] - 6s 304ms/step - loss: 0.0930 - MAE: 0.0930
# Epoch 7/50
# 20/20 [==============================] - 6s 301ms/step - loss: 0.0874 - MAE: 0.0874
# Epoch 8/50
# 20/20 [==============================] - 6s 310ms/step - loss: 0.0817 - MAE: 0.0817
# Epoch 9/50
# 20/20 [==============================] - 7s 359ms/step - loss: 0.0730 - MAE: 0.0730
# Epoch 10/50
# 20/20 [==============================] - 7s 325ms/step - loss: 0.0683 - MAE: 0.0683
# Epoch 11/50
# 20/20 [==============================] - 6s 308ms/step - loss: 0.0666 - MAE: 0.0666
# Epoch 12/50
# 20/20 [==============================] - 6s 282ms/step - loss: 0.0657 - MAE: 0.0657
# Epoch 13/50
# 20/20 [==============================] - 6s 319ms/step - loss: 0.0652 - MAE: 0.0652
# Epoch 14/50
# 20/20 [==============================] - 7s 352ms/step - loss: 0.0652 - MAE: 0.0652
# Epoch 15/50
# 20/20 [==============================] - 6s 306ms/step - loss: 0.0642 - MAE: 0.0642
# Epoch 16/50
# 20/20 [==============================] - 6s 306ms/step - loss: 0.0633 - MAE: 0.0633
# Epoch 17/50
# 20/20 [==============================] - 6s 307ms/step - loss: 0.0599 - MAE: 0.0599
# Epoch 18/50
# 20/20 [==============================] - 6s 319ms/step - loss: 0.0555 - MAE: 0.0555
# Epoch 19/50
# 20/20 [==============================] - 5s 265ms/step - loss: 0.0533 - MAE: 0.0533
# Epoch 20/50
# 20/20 [==============================] - 6s 314ms/step - loss: 0.0524 - MAE: 0.0524
# Epoch 21/50
# 20/20 [==============================] - 6s 285ms/step - loss: 0.0522 - MAE: 0.0522
# Epoch 22/50
# 20/20 [==============================] - 6s 286ms/step - loss: 0.0517 - MAE: 0.0517
# Epoch 23/50
# 20/20 [==============================] - 7s 350ms/step - loss: 0.0514 - MAE: 0.0514
# Epoch 24/50
# 20/20 [==============================] - 5s 263ms/step - loss: 0.0514 - MAE: 0.0514
# Epoch 25/50
# 20/20 [==============================] - 5s 269ms/step - loss: 0.0505 - MAE: 0.0505
# Epoch 26/50
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0503 - MAE: 0.0503
# Epoch 27/50
# 20/20 [==============================] - 4s 221ms/step - loss: 0.0501 - MAE: 0.0501
# Epoch 28/50
# 20/20 [==============================] - 6s 305ms/step - loss: 0.0495 - MAE: 0.0495
# Epoch 29/50
# 20/20 [==============================] - 7s 332ms/step - loss: 0.0495 - MAE: 0.0495
# Epoch 30/50
# 20/20 [==============================] - 4s 210ms/step - loss: 0.0495 - MAE: 0.0495
# Epoch 31/50
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0498 - MAE: 0.0498
# Epoch 32/50
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0498 - MAE: 0.0498
# Epoch 33/50
# 20/20 [==============================] - 5s 229ms/step - loss: 0.0494 - MAE: 0.0494
# Epoch 34/50
# 20/20 [==============================] - 6s 307ms/step - loss: 0.0494 - MAE: 0.0494
# Epoch 35/50
# 20/20 [==============================] - 5s 238ms/step - loss: 0.0491 - MAE: 0.0491
# Epoch 36/50
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0489 - MAE: 0.0489
# Epoch 37/50
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0486 - MAE: 0.0486
# Epoch 38/50
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0470 - MAE: 0.0470
# Epoch 39/50
# 20/20 [==============================] - 4s 224ms/step - loss: 0.0463 - MAE: 0.0463
# Epoch 40/50
# 20/20 [==============================] - 7s 326ms/step - loss: 0.0458 - MAE: 0.0458
# Epoch 41/50
# 20/20 [==============================] - 6s 316ms/step - loss: 0.0456 - MAE: 0.0456
# Epoch 42/50
# 20/20 [==============================] - 5s 259ms/step - loss: 0.0456 - MAE: 0.0456
# Epoch 43/50
# 20/20 [==============================] - 6s 285ms/step - loss: 0.0456 - MAE: 0.0456
# Epoch 44/50
# 20/20 [==============================] - 6s 306ms/step - loss: 0.0450 - MAE: 0.0450
# Epoch 45/50
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0448 - MAE: 0.0448
# Epoch 46/50
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0448 - MAE: 0.0448
# Epoch 47/50
# 20/20 [==============================] - 3s 154ms/step - loss: 0.0448 - MAE: 0.0448
# Epoch 48/50
# 20/20 [==============================] - 3s 157ms/step - loss: 0.0446 - MAE: 0.0446
# Epoch 49/50
# 20/20 [==============================] - 3s 158ms/step - loss: 0.0445 - MAE: 0.0445
# Epoch 50/50
# 20/20 [==============================] - 3s 155ms/step - loss: 0.0446 - MAE: 0.0446

# %% [markdown]
# Let's have a look at a reconstructed image

# %%
origianl_map = training_data[:1]
reconstructed_map = model(origianl_map, True).numpy()

# %%
hp.mollview(origianl_map[0,:,0], nest=True, title="Input Map")
hp.mollview(reconstructed_map[0,:,0], nest=True, title="Reconstruction Map")
hp.mollview(origianl_map[0,:,0] - reconstructed_map[0,:,0], nest=True, title="Difference")

# %% [markdown]
# Let's take a loot at the loss again

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history["loss"], label="Traings Loss")
plt.grid()
plt.yscale("log")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
